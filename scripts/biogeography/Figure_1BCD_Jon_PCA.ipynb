# %%
library("RcppCNPy")
library("ggplot2")
library(ggrepel)
library(dplyr)
library(tidyr)
library(ggpubr)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: magrittr
#
#
# Attaching package: 'magrittr'
#
#
# The following object is masked from 'package:tidyr':
#
#     extract

# %%
both <- as.matrix(read.table("Vanderbilt/both.run.pcangsd.analysis.cov"))

# %%
both.e2 <- as.matrix(read.table("Vanderbilt/both.e2.run.admix.cov"))
both.e3 <- as.matrix(read.table("Vanderbilt/both.e3.run.admix.cov"))
both.e4 <- as.matrix(read.table("Vanderbilt/both.e4.run.admix.cov"))

# %%
location.both <- read.table("Vanderbilt/both.run.tab", sep="\t", header=T)

# %%
e_both <- eigen(both)$vectors
colnames(e_both) <- colnames(both)
e_both.e2 <- eigen(both.e2)$vectors
colnames(e_both.e2) <- colnames(both.e2)
e_both.e3 <- eigen(both.e3)$vectors
colnames(e_both.e3) <- colnames(both.e3)
e_both.e4 <- eigen(both.e4)$vectors
colnames(e_both.e4) <- colnames(both.e4)

# %%
both_df <- data.frame(PC1=as.data.frame(e_both)$V1, 
                     PC2=as.data.frame(e_both)$V2, Sample=location.both$Sample, Location=location.both$Location, 
                            SampleName=location.both$Sample)
both_df.e2 <- data.frame(PC1=as.data.frame(e_both.e2)$V1, 
                     PC2=as.data.frame(e_both.e2)$V2, Sample=location.both$Sample, Location=location.both$Location, 
                            SampleName=location.both$Sample)
both_df.e3 <- data.frame(PC1=as.data.frame(e_both.e3)$V1, 
                     PC2=as.data.frame(e_both.e3)$V2, Sample=location.both$Sample, Location=location.both$Location, 
                            SampleName=location.both$Sample)
both_df.e4 <- data.frame(PC1=as.data.frame(e_both.e4)$V1, 
                     PC2=as.data.frame(e_both.e4)$V2, Sample=location.both$Sample, Location=location.both$Location, 
                            SampleName=location.both$Sample)

# %%
options(repr.plot.width = 12, repr.plot.height = 8)

# %%
e2 <- ggplot(both_df.e2, aes(x=PC1, y=PC2, size=1.5, color=Location, label=Location))  + geom_point() + geom_label_repel(max.overlaps=20)

# %%
e3 <- ggplot(both_df.e3, aes(x=PC1, y=PC2, size=1.5, color=Location, label=Location))  + geom_point() + geom_label_repel(max.overlaps=20)

# %%
e4 <- ggplot(both_df.e4, aes(x=PC1, y=PC2, size=1.5, color=Location, label=Location))  + geom_point() + geom_label_repel(max.overlaps=20)

# %%
e1 <- ggplot(both_df, aes(x=PC1, y=PC2, size=1.5, color=Location, label=Location))  + geom_point() + geom_label_repel(max.overlaps=20)

# %%
options(repr.plot.width = 18, repr.plot.height = 18)

# %%
ggarrange(e1, e2, e3, e4, labels=c("e=1", "e=2", "e=3", "e=4"))
# Out:
# Warning message:
# "ggrepel: 21 unlabeled data points (too many overlaps). Consider increasing max.overlaps"
# Warning message:
# "ggrepel: 23 unlabeled data points (too many overlaps). Consider increasing max.overlaps"
# Warning message:
# "ggrepel: 17 unlabeled data points (too many overlaps). Consider increasing max.overlaps"
# plot without title

# %%
options(repr.plot.width = 12, repr.plot.height = 8)

# %%
ggplot(both_df, aes(x=PC1, y=PC2,  color=Location, label=Location))  + geom_point() + geom_label_repel(max.overlaps=20) + stat_ellipse()
# Out:
# Too few points to calculate an ellipse
# Too few points to calculate an ellipse
# Too few points to calculate an ellipse
# Too few points to calculate an ellipse
# Too few points to calculate an ellipse
# Warning message:
# "Removed 5 rows containing missing values (`geom_path()`)."
# plot without title

# %%
q <- read.table("Vanderbilt/both.run.admix.admix.2.Q")

# %%
barplot(t(q),col=2:10,space=0,border=NA,xlab="Individuals",ylab="Admixture proportions")
# Out:
# plot without title

# %%
plot_data <- cbind(q, location.both) %>% gather("pop.group", "prob", 1:2) %>% arrange(Location, Sample, pop.group)

# %%
plot_data
# Out:
#     Sample  Location           pop.group prob
# 1   CC06    East Grande Terre  V1        0.0734192
# 2   CC06    East Grande Terre  V2        0.9265808
# 3   CC21    East Grande Terre  V1        0.1101224
# 4   CC21    East Grande Terre  V2        0.8898776
# 5   CC27    East Grande Terre  V1        0.1448353
# 6   CC27    East Grande Terre  V2        0.8551647
# 7   CC33    East Grande Terre  V1        0.0936811
# 8   CC33    East Grande Terre  V2        0.9063189
# 9   TK11    East Grande Terre  V1        0.2217854
# 10  TK11    East Grande Terre  V2        0.7782146
# 11  TK12    East Grande Terre  V1        0.1204029
# 12  TK12    East Grande Terre  V2        0.8795971
# 13  MCAMP30 East Malabar       V1        0.0002963
# 14  MCAMP30 East Malabar       V2        0.9997037
# 15  MCAMP31 East Malabar       V1        0.0081740
# 16  MCAMP31 East Malabar       V2        0.9918260
# 17  MCAMP33 East Malabar       V1        0.0001000
# 18  MCAMP33 East Malabar       V2        0.9999000
# 19  MCAMP34 East Malabar       V1        0.0429189
# 20  MCAMP34 East Malabar       V2        0.9570811
# 21  MCAMP35 East Malabar       V1        0.0014660
# 22  MCAMP35 East Malabar       V2        0.9985340
# 23  jon.    Jonathan           V1        0.4143135
# 24  jon.    Jonathan           V2        0.5856866
# 25  MLR1    Middle Malabar     V1        0.0173213
# 26  MLR1    Middle Malabar     V2        0.9826788
# 27  MLR2    Middle Malabar     V1        0.0243845
# 28  MLR2    Middle Malabar     V2        0.9756155
# 29  MLR3    Middle Malabar     V1        0.0001000
# 30  MLR3    Middle Malabar     V2        0.9999000
# ... ...     ...                ...       ...
# 39  DDM18   South Grande Terre V1        0.5171294
# 40  DDM18   South Grande Terre V2        0.4828706
# 41  DDM40   South Grande Terre V1        0.4231257
# 42  DDM40   South Grande Terre V2        0.5768743
# 43  DJL17   South Grande Terre V1        0.6640418
# 44  DJL17   South Grande Terre V2        0.3359582
# 45  DJL24   South Grande Terre V1        0.6127964
# 46  DJL24   South Grande Terre V2        0.3872035
# 47  tank.   Tank               V1        0.4152521
# 48  tank.   Tank               V2        0.5847479
# 49  ANM11   West Grande Terre  V1        0.5466467
# 50  ANM11   West Grande Terre  V2        0.4533533
# 51  ANM14   West Grande Terre  V1        0.4656998
# 52  ANM14   West Grande Terre  V2        0.5343001
# 53  ANM15   West Grande Terre  V1        0.5687330
# 54  ANM15   West Grande Terre  V2        0.4312669
# 55  WMAL2   West Malabar       V1        0.9999000
# 56  WMAL2   West Malabar       V2        0.0001000
# 57  WMAL3   West Malabar       V1        0.9999000
# 58  WMAL3   West Malabar       V2        0.0001000
# 59  WMAL4   West Malabar       V1        0.9999000
# 60  WMAL4   West Malabar       V2        0.0001000
# 61  WMAL5   West Malabar       V1        0.9999000
# 62  WMAL5   West Malabar       V2        0.0001000
# 63  WMAL7   West Malabar       V1        0.9678280
# 64  WMAL7   West Malabar       V2        0.0321720
# 65  ZOO1    Zurich Zoo         V1        0.3594529
# 66  ZOO1    Zurich Zoo         V2        0.6405471
# 67  ZOO2    Zurich Zoo         V1        0.6017502
# 68  ZOO2    Zurich Zoo         V2        0.3982498

# %%
options(repr.plot.width = 12, repr.plot.height = 8)

# %%
colors <- scale_fill_manual(values=c("darkseagreen", "darkslategray4", "deepskyblue3", "lavenderblush3", "indianred"))

# %%
plot_theme <- theme_minimal()  + theme(axis.title.x=element_blank(), axis.text.x=element_blank())

# %%
k2 <- ggplot(plot_data, aes(interaction(Location, Sample), prob, fill=pop.group)) + geom_col() + 
colors + plot_theme 
k2
# Out:
# plot without title

# %%
q.e2 <- read.table("Vanderbilt/both.e2.run.admix.admix.3.Q")

# %%
plot_data.e2 <- cbind(q.e2, location.both) %>% gather("pop.group", "prob", 1:3) %>% arrange(Location, Sample, pop.group)

# %%
plot_data.e2
# Out:
#     Sample  Location          pop.group prob
# 1   CC06    East Grande Terre V1        0.0300557
# 2   CC06    East Grande Terre V2        0.0000986
# 3   CC06    East Grande Terre V3        0.9698457
# 4   CC21    East Grande Terre V1        0.1692889
# 5   CC21    East Grande Terre V2        0.0057509
# 6   CC21    East Grande Terre V3        0.8249602
# 7   CC27    East Grande Terre V1        0.0000989
# 8   CC27    East Grande Terre V2        0.0112427
# 9   CC27    East Grande Terre V3        0.9886585
# 10  CC33    East Grande Terre V1        0.1197194
# 11  CC33    East Grande Terre V2        0.0000997
# 12  CC33    East Grande Terre V3        0.8801810
# 13  TK11    East Grande Terre V1        0.0457869
# 14  TK11    East Grande Terre V2        0.0989042
# 15  TK11    East Grande Terre V3        0.8553088
# 16  TK12    East Grande Terre V1        0.1006230
# 17  TK12    East Grande Terre V2        0.0112464
# 18  TK12    East Grande Terre V3        0.8881306
# 19  MCAMP30 East Malabar      V1        0.9780856
# 20  MCAMP30 East Malabar      V2        0.0218162
# 21  MCAMP30 East Malabar      V3        0.0000982
# 22  MCAMP31 East Malabar      V1        0.9620717
# 23  MCAMP31 East Malabar      V2        0.0242250
# 24  MCAMP31 East Malabar      V3        0.0137033
# 25  MCAMP33 East Malabar      V1        0.9985338
# 26  MCAMP33 East Malabar      V2        0.0000999
# 27  MCAMP33 East Malabar      V3        0.0013663
# 28  MCAMP34 East Malabar      V1        0.8738963
# 29  MCAMP34 East Malabar      V2        0.0459225
# 30  MCAMP34 East Malabar      V3        0.0801812
# ... ...     ...               ...       ...
# 73  ANM11   West Grande Terre V1        0.1334950
# 74  ANM11   West Grande Terre V2        0.4867353
# 75  ANM11   West Grande Terre V3        0.3797697
# 76  ANM14   West Grande Terre V1        0.1104033
# 77  ANM14   West Grande Terre V2        0.3883686
# 78  ANM14   West Grande Terre V3        0.5012280
# 79  ANM15   West Grande Terre V1        0.0788017
# 80  ANM15   West Grande Terre V2        0.5009632
# 81  ANM15   West Grande Terre V3        0.4202352
# 82  WMAL2   West Malabar      V1        0.0054164
# 83  WMAL2   West Malabar      V2        0.9944842
# 84  WMAL2   West Malabar      V3        0.0000995
# 85  WMAL3   West Malabar      V1        0.0016168
# 86  WMAL3   West Malabar      V2        0.9982834
# 87  WMAL3   West Malabar      V3        0.0000998
# 88  WMAL4   West Malabar      V1        0.0022649
# 89  WMAL4   West Malabar      V2        0.9976352
# 90  WMAL4   West Malabar      V3        0.0000998
# 91  WMAL5   West Malabar      V1        0.0000997
# 92  WMAL5   West Malabar      V2        0.9964560
# 93  WMAL5   West Malabar      V3        0.0034443
# 94  WMAL7   West Malabar      V1        0.0060691
# 95  WMAL7   West Malabar      V2        0.9584798
# 96  WMAL7   West Malabar      V3        0.0354512
# 97  ZOO1    Zurich Zoo        V1        0.1442159
# 98  ZOO1    Zurich Zoo        V2        0.2749531
# 99  ZOO1    Zurich Zoo        V3        0.5808309
# 100 ZOO2    Zurich Zoo        V1        0.0702862
# 101 ZOO2    Zurich Zoo        V2        0.5403619
# 102 ZOO2    Zurich Zoo        V3        0.3893519

# %%
k3 <- ggplot(plot_data.e2, aes(interaction(Location, Sample), prob, fill=pop.group)) + geom_col() + 
theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1)) +
colors + plot_theme
k3
# Out:
# plot without title

# %%
q.e3 <- read.table("Vanderbilt/both.e3.run.admix.admix.4.Q")
plot_data.e3 <- cbind(q.e3, location.both) %>% gather("pop.group", "prob", 1:4) %>% arrange(Location, Sample, pop.group)
plot_data.e3
# Out:
#     Sample  Location          pop.group prob
# 1   CC06    East Grande Terre V1        0.0234770
# 2   CC06    East Grande Terre V2        0.0000990
# 3   CC06    East Grande Terre V3        0.9763249
# 4   CC06    East Grande Terre V4        0.0000990
# 5   CC21    East Grande Terre V1        0.1442254
# 6   CC21    East Grande Terre V2        0.0001003
# 7   CC21    East Grande Terre V3        0.8242048
# 8   CC21    East Grande Terre V4        0.0314695
# 9   CC27    East Grande Terre V1        0.0000985
# 10  CC27    East Grande Terre V2        0.0398614
# 11  CC27    East Grande Terre V3        0.9599416
# 12  CC27    East Grande Terre V4        0.0000985
# 13  CC33    East Grande Terre V1        0.1088619
# 14  CC33    East Grande Terre V2        0.0126424
# 15  CC33    East Grande Terre V3        0.8783951
# 16  CC33    East Grande Terre V4        0.0001006
# 17  TK11    East Grande Terre V1        0.0291480
# 18  TK11    East Grande Terre V2        0.0667014
# 19  TK11    East Grande Terre V3        0.8219008
# 20  TK11    East Grande Terre V4        0.0822498
# 21  TK12    East Grande Terre V1        0.0835850
# 22  TK12    East Grande Terre V2        0.0637901
# 23  TK12    East Grande Terre V3        0.8525242
# 24  TK12    East Grande Terre V4        0.0001006
# 25  MCAMP30 East Malabar      V1        0.9364854
# 26  MCAMP30 East Malabar      V2        0.0000976
# 27  MCAMP30 East Malabar      V3        0.0000976
# 28  MCAMP30 East Malabar      V4        0.0633195
# 29  MCAMP31 East Malabar      V1        0.9284478
# 30  MCAMP31 East Malabar      V2        0.0626127
# ... ...     ...               ...       ...
# 107 ANM15   West Grande Terre V3        0.0001002
# 108 ANM15   West Grande Terre V4        0.0543854
# 109 WMAL2   West Malabar      V1        0.0013437
# 110 WMAL2   West Malabar      V2        0.0000993
# 111 WMAL2   West Malabar      V3        0.0160277
# 112 WMAL2   West Malabar      V4        0.9825293
# 113 WMAL3   West Malabar      V1        0.0001001
# 114 WMAL3   West Malabar      V2        0.0039225
# 115 WMAL3   West Malabar      V3        0.0067817
# 116 WMAL3   West Malabar      V4        0.9891957
# 117 WMAL4   West Malabar      V1        0.0000989
# 118 WMAL4   West Malabar      V2        0.0483936
# 119 WMAL4   West Malabar      V3        0.0000989
# 120 WMAL4   West Malabar      V4        0.9514086
# 121 WMAL5   West Malabar      V1        0.0001002
# 122 WMAL5   West Malabar      V2        0.0056498
# 123 WMAL5   West Malabar      V3        0.0153872
# 124 WMAL5   West Malabar      V4        0.9788628
# 125 WMAL7   West Malabar      V1        0.0001008
# 126 WMAL7   West Malabar      V2        0.1134865
# 127 WMAL7   West Malabar      V3        0.0010232
# 128 WMAL7   West Malabar      V4        0.8853894
# 129 ZOO1    Zurich Zoo        V1        0.1191995
# 130 ZOO1    Zurich Zoo        V2        0.4874002
# 131 ZOO1    Zurich Zoo        V3        0.3378576
# 132 ZOO1    Zurich Zoo        V4        0.0555426
# 133 ZOO2    Zurich Zoo        V1        0.0335886
# 134 ZOO2    Zurich Zoo        V2        0.7848445
# 135 ZOO2    Zurich Zoo        V3        0.0278098
# 136 ZOO2    Zurich Zoo        V4        0.1537570

# %%
k4 <- ggplot(plot_data.e3, aes(interaction(Location, Sample), prob, fill=pop.group)) + geom_col() + 
theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1)) +
colors + plot_theme
k4
# Out:
# plot without title

# %%
q.e4 <- read.table("Vanderbilt/both.e4.run.admix.admix.5.Q")
plot_data.e4 <- cbind(q.e4, location.both) %>% gather("pop.group", "prob", 1:5) %>% arrange(Location, Sample, pop.group)
plot_data.e4
# Out:
#     Sample Location          pop.group prob
# 1   CC06   East Grande Terre V1        0.9446388
# 2   CC06   East Grande Terre V2        0.0054015
# 3   CC06   East Grande Terre V3        0.0001000
# 4   CC06   East Grande Terre V4        0.0497595
# 5   CC06   East Grande Terre V5        0.0001000
# 6   CC21   East Grande Terre V1        0.7613541
# 7   CC21   East Grande Terre V2        0.1112743
# 8   CC21   East Grande Terre V3        0.0000990
# 9   CC21   East Grande Terre V4        0.0000990
# 10  CC21   East Grande Terre V5        0.1271736
# 11  CC27   East Grande Terre V1        0.8870279
# 12  CC27   East Grande Terre V2        0.0000974
# 13  CC27   East Grande Terre V3        0.0000974
# 14  CC27   East Grande Terre V4        0.0000974
# 15  CC27   East Grande Terre V5        0.1126798
# 16  CC33   East Grande Terre V1        0.7358161
# 17  CC33   East Grande Terre V2        0.0401625
# 18  CC33   East Grande Terre V3        0.0000989
# 19  CC33   East Grande Terre V4        0.2238235
# 20  CC33   East Grande Terre V5        0.0000989
# 21  TK11   East Grande Terre V1        0.7839003
# 22  TK11   East Grande Terre V2        0.0050932
# 23  TK11   East Grande Terre V3        0.0709194
# 24  TK11   East Grande Terre V4        0.0577115
# 25  TK11   East Grande Terre V5        0.0823757
# 26  TK12   East Grande Terre V1        0.8020267
# 27  TK12   East Grande Terre V2        0.0537568
# 28  TK12   East Grande Terre V3        0.0001013
# 29  TK12   East Grande Terre V4        0.1332791
# 30  TK12   East Grande Terre V5        0.0108360
# ... ...    ...               ...       ...
# 141 WMAL3  West Malabar      V1        0.0000997
# 142 WMAL3  West Malabar      V2        0.0000997
# 143 WMAL3  West Malabar      V3        0.9716077
# 144 WMAL3  West Malabar      V4        0.0280931
# 145 WMAL3  West Malabar      V5        0.0000997
# 146 WMAL4  West Malabar      V1        0.0000990
# 147 WMAL4  West Malabar      V2        0.0000990
# 148 WMAL4  West Malabar      V3        0.9450765
# 149 WMAL4  West Malabar      V4        0.0203078
# 150 WMAL4  West Malabar      V5        0.0344177
# 151 WMAL5  West Malabar      V1        0.0079190
# 152 WMAL5  West Malabar      V2        0.0001001
# 153 WMAL5  West Malabar      V3        0.9679673
# 154 WMAL5  West Malabar      V4        0.0239134
# 155 WMAL5  West Malabar      V5        0.0001001
# 156 WMAL7  West Malabar      V1        0.0032242
# 157 WMAL7  West Malabar      V2        0.0001007
# 158 WMAL7  West Malabar      V3        0.8630077
# 159 WMAL7  West Malabar      V4        0.0001007
# 160 WMAL7  West Malabar      V5        0.1335668
# 161 ZOO1   Zurich Zoo        V1        0.1478392
# 162 ZOO1   Zurich Zoo        V2        0.0147494
# 163 ZOO1   Zurich Zoo        V3        0.0315073
# 164 ZOO1   Zurich Zoo        V4        0.8058045
# 165 ZOO1   Zurich Zoo        V5        0.0000996
# 166 ZOO2   Zurich Zoo        V1        0.0330521
# 167 ZOO2   Zurich Zoo        V2        0.0276824
# 168 ZOO2   Zurich Zoo        V3        0.0754957
# 169 ZOO2   Zurich Zoo        V4        0.0001002
# 170 ZOO2   Zurich Zoo        V5        0.8636696

# %%
options(repr.plot.width = 12, repr.plot.height = 8)

# %%
k5 <- ggplot(plot_data.e4, aes(interaction(Location, Sample), prob, fill=pop.group, label=Location)) + 
geom_col() + theme_minimal() +
theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1)) +
#plot_theme +
colors
k5
# Out:
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 12)

# %%
ggarrange(k2, k3, k4, k5, ncol=1, heights=c(1,1,1,2), labels=c("K=2", "K=3", "K=4", "K=5"), legend="none")
# Out:
# plot without title
